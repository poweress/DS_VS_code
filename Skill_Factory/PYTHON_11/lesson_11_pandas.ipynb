# %%
import pandas as pd

# %%
melb_data = pd.read_csv('data/melb_data_ps.csv', sep=',')

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df = melb_data.copy()
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df.drop(['index','Coordinates'], axis=1, inplace=True)
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5      3067  ...         1    1     202.0         126.0
# 1  4/02/2016       2.5      3067  ...         1    0     156.0          79.0
# 2  4/03/2017       2.5      3067  ...         2    0     134.0         150.0
# 3  4/03/2017       2.5      3067  ...         2    1      94.0         126.0
# 4  4/06/2016       2.5      3067  ...         1    2     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
melb_df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
total_rooms = melb_df['Rooms'] + melb_df['Bedroom'] + melb_df['Bathroom']

# %%
display(total_rooms)
# Out:
# 0         5
# 1         5
# 2         8
# 3         8
# 4         8
#          ..
# 13575    10
# 13576     8
# 13577     8
# 13578     9
# 13579     9
# Length: 13580, dtype: int64

# %%
melb_df['MeanRoomsSquare'] = melb_df['BuildingArea'] / total_rooms
display(melb_df['MeanRoomsSquare'])
# Out:
# 0        25.200000
# 1        15.800000
# 2        18.750000
# 3        15.750000
# 4        17.750000
#            ...
# 13575    12.600000
# 13576    16.625000
# 13577    15.750000
# 13578    17.444444
# 13579    12.444444
# Name: MeanRoomsSquare, Length: 13580, dtype: float64

# %%
diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area
display(melb_df['AreaRatio'])
# Out:
# 0       -0.231707
# 1       -0.327660
# 2        0.056338
# 3        0.145455
# 4        0.083969
#            ...
# 13575   -0.676093
# 13576   -0.429185
# 13577   -0.551601
# 13578   -0.693060
# 13579   -0.527426
# Name: AreaRatio, Length: 13580, dtype: float64

# %% [markdown]
# Что показывает такой коэффициент? Если присмотреться, можно увидеть, что AreaRatio лежит в интервале от -1 до 1.
#
# Рассмотрим три случая, чтобы понять его значение:
#
# Если рассматриваемые площади равны, то числитель дроби зануляется и коэффициент тоже равен 0.
# Если одна из площадей начинает доминировать над другой, то коэффициент начинает расти в отрицательную сторону, если площадь участка больше площади здания, и в положительную сторону, если наоборот.
# Наконец, в предельном случае, если площадь здания равна 0, то числитель дроби равен знаменателю со знаком минус, а коэффициент равен -1, а если площадь участка равна 0, то числитель дроби равен знаменателю со знаком плюс, а коэффициент равен 1.
# Таким образом, значение в столбце AreaRatio служит своеобразным указателем соотношения площадей объекта недвижимости. Для пустырей — участков без строений — он будет равен -1, для домов без территории — 1, во всех остальных случаях мы можем увидеть, какая площадь больше — здания или участка.

# %%
price_square = []
for price in melb_df['Price']:
    price_square.append(price**2)
price_square = pd.Series(price_square)

# %%
price_square
# Out:
# 0        2.190400e+12
# 1        1.071225e+12
# 2        2.146225e+12
# 3        7.225000e+11
# 4        2.560000e+12
#              ...
# 13575    1.550025e+12
# 13576    1.062961e+12
# 13577    1.368900e+12
# 13578    6.250000e+12
# 13579    1.651225e+12
# Length: 13580, dtype: float64

# %%
price_square = melb_df['Price'] * 2

# %%
price_square
# Out:
# 0        2960000.0
# 1        2070000.0
# 2        2930000.0
# 3        1700000.0
# 4        3200000.0
#            ...
# 13575    2490000.0
# 13576    2062000.0
# 13577    2340000.0
# 13578    5000000.0
# 13579    2570000.0
# Name: Price, Length: 13580, dtype: float64

# %%
price_square = melb_df['Price'] **2
display(price_square)
# Out:
# 0        2.190400e+12
# 1        1.071225e+12
# 2        2.146225e+12
# 3        7.225000e+11
# 4        2.560000e+12
#              ...
# 13575    1.550025e+12
# 13576    1.062961e+12
# 13577    1.368900e+12
# 13578    6.250000e+12
# 13579    1.651225e+12
# Name: Price, Length: 13580, dtype: float64

# %%
customer_df = pd.DataFrame({
        'number': [0, 1, 2, 3, 4],
        'cust_id': [128, 1201, 9832, 4392, 7472],
        'cust_age': [13, 21, 19, 21, 60],
        'cust_sale': [0, 0, 0.2, 0.15, 0.3],
        'cust_year_birth': [2008, 2000, 2002, 2000, 1961],
        'cust_order': [1400, 14142, 900, 1240, 8430]
    })
display(customer_df)
# Out:
#    number  cust_id  cust_age  cust_sale  cust_year_birth  cust_order
# 0       0      128        13       0.00             2008        1400
# 1       1     1201        21       0.00             2000       14142
# 2       2     9832        19       0.20             2002         900
# 3       3     4392        21       0.15             2000        1240
# 4       4     7472        60       0.30             1961        8430

# %%
import pandas as pd

def delete_columns(df, col=[]):
    """
    Напишите функцию delete_columns(df, col=[]), которая удаляет столбцы из DataFrame и возвращает новую таблицу. 
    Если одного из указанных столбцов в таблице не существует, то функция должна возвращать None.
    """
    
    for c in col:
        if c not in df.columns:
            return None
        return df.drop(col, axis=1)

if __name__ == '__main__':
    customer_df = pd.DataFrame({
        'number': [0, 1, 2, 3, 4],
        'cust_id': [128, 1201, 9832, 4392, 7472],
        'cust_age': [13, 21, 19, 21, 60],
        'cust_sale': [0, 0, 0.2, 0.15, 0.3],
        'cust_year_birth': [2008, 2000, 2002, 2000, 1961],
        'cust_order': [1400, 14142, 900, 1240, 8430]
    })
    columns_for_delete= ['number', 'cust_age'] #выбранные вами столбцы
    
    new_df = delete_columns(customer_df, columns_for_delete)
    print(new_df)
# Out:
#    cust_id  cust_sale  cust_year_birth  cust_order
# 0      128       0.00             2008        1400
# 1     1201       0.00             2000       14142
# 2     9832       0.20             2002         900
# 3     4392       0.15             2000        1240
# 4     7472       0.30             1961        8430

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
countries_df['density'] = round(countries_df['population'] / countries_df['square'] * 1e6, 2)
display(countries_df.head())
# Out:
#    country  population    square  density
# 0   Англия       56.29    133396   421.98
# 1   Канада       38.05   9984670     3.81
# 2      США      322.28   9826630    32.80
# 3   Россия      146.24  17125191     8.54
# 4  Украина       45.50    603628    75.38

# %%
countries_df['density'].mean()
# Out:
# 84.93142857142857

# %%
display(melb_data['Date'])
# Out:
# 0         3/12/2016
# 1         4/02/2016
# 2         4/03/2017
# 3         4/03/2017
# 4         4/06/2016
#             ...
# 13575    26/08/2017
# 13576    26/08/2017
# 13577    26/08/2017
# 13578    26/08/2017
# 13579    26/08/2017
# Name: Date, Length: 13580, dtype: object

# %%
seconds_series = pd.Series(pd.date_range("2000-01-01", periods=4, freq="q"))
seconds_series
# Out:
# 0   2000-03-31
# 1   2000-06-30
# 2   2000-09-30
# 3   2000-12-31
# dtype: datetime64[ns]

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True)

display(melb_df['Date'])
# Out:
# 0       2016-12-03
# 1       2016-02-04
# 2       2017-03-04
# 3       2017-03-04
# 4       2016-06-04
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
years_sold = melb_df['Date'].dt.year
print(years_sold)
print('Min year sold:', years_sold.min())
print('Max year sold:', years_sold.max())
print('Mode year sold:', years_sold.mode()[0])
# Out:
# 0        2016
# 1        2016
# 2        2017
# 3        2017
# 4        2016
#          ...
# 13575    2017
# 13576    2017
# 13577    2017
# 13578    2017
# 13579    2017
# Name: Date, Length: 13580, dtype: int64
# Min year sold: 2016
# Max year sold: 2017
# Mode year sold: 2017

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].value_counts(normalize=True)
# Out:
# 5     0.149411
# 7     0.145950
# 9     0.135862
# 6     0.134757
# 8     0.114138
# 11    0.082032
# 4     0.069882
# 3     0.049926
# 12    0.044698
# 10    0.040574
# 2     0.032622
# 1     0.000147
# Name: MonthSale, dtype: float64

# %%
delta_day = melb_df['Date'] - pd.to_datetime('2016-01-01')

# %%
display(delta_day)
# Out:
# 0       337 days
# 1        34 days
# 2       428 days
# 3       428 days
# 4       155 days
#           ...
# 13575   603 days
# 13576   603 days
# 13577   603 days
# 13578   603 days
# 13579   603 days
# Name: Date, Length: 13580, dtype: timedelta64[ns]

# %%
display(delta_day.dt.days)
# Out:
# 0        337
# 1         34
# 2        428
# 3        428
# 4        155
#         ...
# 13575    603
# 13576    603
# 13577    603
# 13578    603
# 13579    603
# Name: Date, Length: 13580, dtype: int64

# %%
melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']
display(melb_df['AgeBuilding'])
# Out:
# 0         46
# 1        116
# 2        117
# 3         47
# 4          2
#         ...
# 13575     36
# 13576     22
# 13577     20
# 13578     97
# 13579     97
# Name: AgeBuilding, Length: 13580, dtype: int64

# %%
melb_df = melb_df.drop('YearBuilt', axis=1)

# %%
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  BuildingArea  CouncilArea  Lattitude  \
# 0 2016-12-03       2.5      3067  ...         126.0        Yarra   -37.7996
# 1 2016-02-04       2.5      3067  ...          79.0        Yarra   -37.8079
# 2 2017-03-04       2.5      3067  ...         150.0        Yarra   -37.8093
# 3 2017-03-04       2.5      3067  ...         126.0        Yarra   -37.7969
# 4 2016-06-04       2.5      3067  ...         142.0        Yarra   -37.8072
#
#    Longtitude             Regionname Propertycount  MeanRoomsSquare  \
# ...

# %%
melb_df['WeekdaySale'] = pd.to_datetime(melb_df['WeekdaySale']).dt.week
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WeekdaySale'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-6fba4aaf7fb3> in <module>
# ...

# %% [markdown]
# ✍ Мы рассмотрели основные концепции работы с временными признаками в DataFrame.
#
# Временные признаки часто становятся важной частью анализа данных и построения моделей, особенно когда тематика связана со сферой, в которой присутствует непостоянство во времени (зависимость от месяца, дня недели, времени суток), например сфера продаж и услуг. Важно уметь работать с такими признаками, чтобы извлекать из представленных данных максимум полезной информации и строить качественные прогнозы.
#
# А теперь предлагаем вам закрепить пройденный материал ↓

# %%
melb_df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
melb_df['WeekdaySale'] = melb_df['Date'].dt.dayofweek

# %%
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  CouncilArea  Lattitude  Longtitude  \
# 0 2016-12-03       2.5      3067  ...        Yarra   -37.7996    144.9984
# 1 2016-02-04       2.5      3067  ...        Yarra   -37.8079    144.9934
# 2 2017-03-04       2.5      3067  ...        Yarra   -37.8093    144.9944
# 3 2017-03-04       2.5      3067  ...        Yarra   -37.7969    144.9969
# 4 2016-06-04       2.5      3067  ...        Yarra   -37.8072    144.9941
#
#               Regionname  Propertycount MeanRoomsSquare  AreaRatio  MonthSale  \
# ...

# %%
weekend_count = melb_df[(melb_df['WeekdaySale'] == 5) | (melb_df['WeekdaySale'] == 6)].shape[0]

# %%
display(weekend_count)
# Out:
# 12822

# %%
melb_df.loc[0,'WeekdaySale']
# Out:
# 5

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv',sep=',')

# %%
df_copy = df1.to_csv('data/DF_NLO.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-9b37ee1ccfce> in <module>
# ----> 1 df_copy = df1.to_csv('data/DF_NLO.csv')
#
# NameError: name 'df1' is not defined

# %%
df1.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df1.info
# Out:
# <bound method DataFrame.info of                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...

# %%
df1.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
df1['Time'] = pd.to_datetime(df1['Time'])

# %%
df1['Time'].dt.year.max()
# Out:
# 2000

# %%
df1.shape
# Out:
# (18241, 5)

# %%
df1['Time'].dt.year.mode()
# Out:
# 0    1999
# dtype: int64

# %%
df1.describe()
# Out:
#            City Colors Reported Shape Reported  State                 Time
# count     18216            2882          15597  18241                18241
# unique     6476              27             27     52                16145
# top     Seattle             RED          LIGHT     CA  1999-11-16 19:00:00
# freq        187             780           2803   2529                   27
# first       NaN             NaN            NaN    NaN  1930-06-01 22:00:00
# last        NaN             NaN            NaN    NaN  2000-12-31 23:59:00

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#                City Colors Reported Shape Reported State                Time
# 12           Belton             RED         SPHERE    SC 1939-06-30 20:00:00
# 19       Bering Sea             RED          OTHER    AK 1943-04-30 23:00:00
# 36       Portsmouth             RED      FORMATION    VA 1945-07-10 01:30:00
# 44        Blairsden           GREEN         SPHERE    CA 1946-06-30 19:00:00
# 82         San Jose            BLUE        CHEVRON    CA 1947-07-15 21:00:00
# ...             ...             ...            ...   ...                 ...
# 18213      Pasadena           GREEN       FIREBALL    CA 2000-12-28 19:10:00
# 18216  Garden Grove          ORANGE          LIGHT    CA 2000-12-29 16:10:00
# 18220   Shasta Lake            BLUE           DISK    CA 2000-12-29 20:30:00
# 18233     Anchorage             RED        VARIOUS    AK 2000-12-31 21:00:00
# 18239   Eagle River             RED          LIGHT    WI 2000-12-31 23:45:00
#
# [2486 rows x 5 columns]

# %%
df1.describe()
# Out:
#            City Colors Reported Shape Reported State                 Time
# count      2486            2486           2486  2486                 2486
# unique     1623              26             25    50                 2346
# top     Seattle             RED          LIGHT    CA  1999-11-16 18:05:00
# freq         24             650            575   389                   14
# first       NaN             NaN            NaN   NaN  1939-06-30 20:00:00
# last        NaN             NaN            NaN   NaN  2000-12-31 23:45:00

# %%
df1['City']
# Out:
# 12             Belton
# 19         Bering Sea
# 36         Portsmouth
# 44          Blairsden
# 82           San Jose
#              ...
# 18213        Pasadena
# 18216    Garden Grove
# 18220     Shasta Lake
# 18233       Anchorage
# 18239     Eagle River
# Name: City, Length: 2486, dtype: object

# %%
df1['Time'].mode()[0]
# Out:
# Timestamp('1999-11-16 18:05:00')

# %%
df1.loc[100:800, 'City': 'Time']
# Out:
#                   City Colors Reported Shape Reported State  \
# 111       Tarrant City          ORANGE         CIRCLE    AL
# 129               Napa           GREEN           DISK    CA
# 138      Coeur d'Alene          ORANGE          CIGAR    ID
# 152             Irving            BLUE           DISK    KS
# 157         Greenville           GREEN           DISK    MS
# 163        Green River           GREEN         SPHERE    WY
# 164              Provo            BLUE           DISK    UT
# 174         Greenville          ORANGE       TRIANGLE    TX
# 178            Norfolk             RED       FIREBALL    VA
# 202          Arlington           GREEN           OVAL    VA
# 226          Cambridge             RED         SPHERE    MA
# 229       Midwest City          YELLOW       FIREBALL    OK
# 238          Cleveland             RED       FIREBALL    OH
# 249            Artesia          ORANGE          OTHER    NM
# 256          Pendleton           GREEN           DISK    IN
# ...

# %%
city = df1['City']
for i in city:
    print(i)

# %%
df1['Time'].dt.date.mode()
# Out:
# 0    1999-11-16
# dtype: object

# %%
df1['Date'] = df1['Time'].dt.date
print(df1[df1['State']=='NV']['Date'].diff().dt.days.mean())
# Out:
# 349.77142857142854

# %%
df1.
# Out:
#                   City    Colors Reported Shape Reported State  \
# 18239      Eagle River                RED          LIGHT    WI
# 18233        Anchorage                RED        VARIOUS    AK
# 18220      Shasta Lake               BLUE           DISK    CA
# 18216     Garden Grove             ORANGE          LIGHT    CA
# 18213         Pasadena              GREEN       FIREBALL    CA
# 18210  Monument Valley               BLUE          OTHER    UT
# 18197       Greenfiled              GREEN       FIREBALL    MA
# 18196          Brocton              GREEN           OVAL    MA
# 18194          Walpole              GREEN       FIREBALL    NH
# 18195          Walpole              GREEN       FIREBALL    NH
# 18192          Atlanta             ORANGE          LIGHT    GA
# 18191         Fallston                RED        VARIOUS    MD
# 18184         Plymouth              GREEN       FIREBALL    OH
# 18181          Fortuna             ORANGE         CIRCLE    CA
# ...

# %%
import pandas as pd
df_sh = pd.read_csv('data/schulte_results.csv', sep='|')
display(df_sh)
# Out:
#                      dates   result
# 0    28.04.2022 - 07:32:49   90,902
# 1    28.04.2022 - 07:31:17   85,694
# 2    28.04.2022 - 07:29:51   98,758
# 3    26.04.2022 - 17:11:34  138,726
# 4    26.04.2022 - 08:24:34   92,950
# ..                     ...      ...
# 406  15.10.2021 - 07:23:48   94,715
# 407  15.10.2021 - 07:22:12   74,029
# 408  14.10.2021 - 09:02:58   92,483
# 409  14.10.2021 - 07:20:07   77,068
# 410  13.10.2021 - 22:10:56   91,631
#
# [411 rows x 2 columns]

# %%
df_sh['dates'] =  pd.to_datetime(df_sh['dates'])

# %%
df_dh = pd.DatetimeIndex(df_sh['dates'])

# %%
df_sh.astype({'result': 'float64'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-3390f556b133> in <module>
# ----> 1 df_sh.astype({'result': 'float64'})
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5681                 if col_name in dtype:
#    5682                     results.append(
# -> 5683                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5684                     )
#    5685                 else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ...

# %%
df_sh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411 entries, 0 to 410
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   dates   411 non-null    datetime64[ns]
#  1   result  411 non-null    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 6.5+ KB

# %%
df_sh['result'] = pd.to_numeric(df_sh['result'], errors='coerce')

# %%
df_sh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411 entries, 0 to 410
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   dates   411 non-null    datetime64[ns]
#  1   result  0 non-null      float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 6.5 KB

# %%
df_sh['dates'].dt.month
# Out:
#   File "<ipython-input-194-f4dfc7b45694>", line 1
#     df_sh['dates'].dt.month[]
#                             ^
# SyntaxError: invalid syntax

# %%
df_sh['dates'].plot()

# %%
df_sh['dates'].sort_values().plot()

# %%
firg, ax = plt.subplot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-7b73b0821ac5> in <module>
# ----> 1 firg, ax = plt.subplot()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
matplotlib.__version__
# %matplotlib inline

# %%
melb_df.shape
# Out:
# (13580, 24)

# %%
print(melb_df['Address'].nunique())
# Out:
# 13378

# %%
print(melb_df['Address'].loc[177])
print(melb_df['Address'].loc[1812])
print(melb_df['Address'].loc[9001])
# Out:
# 2/119 Railway St N
# 9/400 Dandenong Rd
# 172 Danks St

# %%
def get_street_type(address):
    # Создаем список географических пометок exclude_list
    exclude_list = ['N', 'S', 'W', 'E']
    #  Метод split() разбивает строку на слова по пробелу.
    # В результате получаем список словв строке и заносим его в переменную address_list
    address_list = address.split(' ')
    # Обрезаем список, оставляя в нем только последние элемент,
    # потенциальный подтип улицы, и заносим в переменную street_type.
    street_type = address_list[-1]
    # Делаем проверку на то, что полученный подтип являетсягеогравической пометкой.
    # Для этого проверяем его на наличие в списке exlude_list.
    if street_type in exclude_list:
        # Если переменная street_list является географической пометкой,
        # переопредиляем ее на второй элемент с конца списка address_list.
        street_type = address_list[-2]
    # Возвращаем переменную street_type, в которой хранится подтип улицы.
        return street_type

# %%
street_types = melb_df['Address'].apply(get_street_type)
display(street_types)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 13575    None
# 13576    None
# 13577    None
# 13578    None
# 13579    None
# Name: Address, Length: 13580, dtype: object

# %%
print(street_types.nunique())
# Out:
# 4

# %%
display(street_types.value_counts())
# Out:
# St     8
# Pde    2
# Pl     1
# Rd     1
# Name: Address, dtype: int64
